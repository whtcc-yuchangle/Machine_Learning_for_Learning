# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os

# 1.创建绘图对象，指定尺寸为5*3英寸
plt.figure(figsize=(5,3))

# 2.给定x轴和y轴数据 - 这一步往往也是创建函数
x = np.linspace(0,2*np.pi) # x轴
y = np.sin(x) # 正弦

# 3.绘制sin函数的图像
plt.plot(x,y)

# 在同一个绘图对象中可以同时绘制多个图像
m = np.cos(x)
plt.plot(x,m)

# 4.设置网格线
plt.grid(
    linestyle = '--', # 样式
    color = 'green', # 颜色
    alpha = 0.75 # 透明度
) 

# 5.设置坐标轴范围
plt.axis([-1,10,-1.5,1.5])

# 6.保存图像文件为图片格式

# 6.1 检查是否存在03th_img文件夹
if not os.path.exists('./03th_img'):
    os.makedirs('./03th_img')

plt.savefig(
    './03th_img/img1.png', # 文件名：png、jpg、pdf
    dpi = 100, # 保存图片像素密度
    facecolor = 'white', # 视图与边界之间颜色设置
    edgecolor = 'red', # 视图边界颜色设置
    bbox_inches = 'tight'# 保存图片完整
)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# 1.创建绘图对象，指定尺寸为5*3英寸
plt.figure(figsize=(5,3))

# 2.给定x轴和y轴数据 - 这一步往往也是创建函数
x = np.linspace(0,2*np.pi,20) # x轴
y1 = np.sin(x) # 正弦
y2 = np.cos(x) # 余弦

# 3.设置颜色，线型，点型
plt.plot(x,y1,color = 'indigo',ls = '-.',marker = 'p')
plt.plot(x,y2,color = '#FF00EE',ls = '--',marker = 'o')
plt.plot(x,y1 + y2,color = (0.2,0.7,0.2),marker = '*',ls = ':')
plt.plot(x,y1 + 2*y2,linewidth = 3,alpha = 0.7,color = 'orange') # 线宽、透明度
plt.plot(x,2*y1 - y2,'bo--') # 参数连用

# 4.保存图像文件为图片格式
plt.savefig(
    './03th_img/img2.png', # 文件名：png、jpg、pdf
    dpi = 100, # 保存图片像素密度
    facecolor = 'white', # 视图与边界之间颜色设置
    edgecolor = 'red', # 视图边界颜色设置
    bbox_inches = 'tight'# 保存图片完整
)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# 1.创建绘图对象，指定尺寸为5*3英寸
plt.figure(figsize=(5,3))

# 2.给定x轴和y轴数据 - 这一步往往也是创建函数
def f(x):
    return np.exp(-x) * np.cos(2*np.pi*x)

x = np.linspace(0,5,50)

# 3.设置颜色，线型，点型
plt.plot(x,f(x),color = 'purple',
         marker = 'o',
         ls = '--',
         lw = 2,
         alpha = 0.6,
         markerfacecolor = 'red',# 点颜色
         markersize = 10,# 点大小
         markeredgecolor = 'green',# 点边缘颜色
         markeredgewidth = 3 # 点边缘宽度
        )

# 4.设置刻度大小
plt.xticks(size = 18) 
plt.yticks(size = 18)

# 5.保存图像文件为图片格式
plt.savefig(
    './03th_img/img3.png', # 文件名：png、jpg、pdf
    dpi = 100, # 保存图片像素密度
    facecolor = 'white', # 视图与边界之间颜色设置
    edgecolor = 'red', # 视图边界颜色设置
    bbox_inches = 'tight'# 保存图片完整
)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# 1.创建绘图对象，指定尺寸为5*3英寸
plt.figure(figsize=(5,3))

# 2.给定x轴和y轴数据 - 这一步往往也是创建函数
x = np.linspace(-np.pi,np.pi,50)
y = np.sin(x)

# 子视图1的绘图
ax = plt.subplot(2,2,1) # 两行两列第一个子视图
ax.plot(x,y,color = 'red')

# 调用子视图设置方法，设置子视图整体属性
ax.set_facecolor('green') 

# 子视图2
ax = plt.subplot(2,2,2) # 两行两列第二个子视图
line, = ax.plot(x,-y) # 返回绘制对象
line.set_marker('*') # 调用对象设置方法，设置属性
line.set_markerfacecolor('red')
line.set_markeredgecolor('green')
line.set_markersize(10)

# 子视图3
ax = plt.subplot(2,1,2) # 两行一列第二行视图
plt.sca(ax) # 设置轴为当前视图，即设置在当前视图上继续绘图
x = np.linspace(-np.pi,np.pi,200)
plt.plot(x,np.sin(x*x),color = 'red')

# 5.保存图像文件为图片格式
plt.savefig(
    './03th_img/img4.png', # 文件名：png、jpg、pdf
    dpi = 100, # 保存图片像素密度
    facecolor = 'white', # 视图与边界之间颜色设置
    edgecolor = 'red', # 视图边界颜色设置
    bbox_inches = 'tight'# 保存图片完整
)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# 1.创建绘图对象，指定尺寸为5*3英寸
fig = plt.figure(figsize=(5,3))

# 2.给定x轴和y轴数据 - 这一步往往也是创建函数
x = np.linspace(-np.pi,np.pi,25)
y = np.sin(x)

# 3.绘制一个图像
plt.plot(x,y)

# 嵌套方式一，axes轴域（横纵坐标范围），子视图
ax = plt.axes([0.2,0.55,0.3,0.3]) # 参数含义[left, bottom, width, height]
ax.plot(x,y,color = 'g')

# 嵌套方式二
ax = fig.add_axes([0.55,0.2,0.3,0.3]) # 使用视图对象添加子视图
ax.plot(x,y,color = 'r')

# 4.保存图像文件为图片格式
plt.savefig(
    './03th_img/img5.png', # 文件名：png、jpg、pdf
    dpi = 100, # 保存图片像素密度
    facecolor = 'white', # 视图与边界之间颜色设置
    edgecolor = 'red', # 视图边界颜色设置
    bbox_inches = 'tight'# 保存图片完整
)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# 1.创建绘图，以3阶方阵返回子视图
fig, ((ax11,ax12,ax13),(ax21,ax22,ax23),(ax31,ax32,ax33)) = plt.subplots(3, 3)

# 2.给定x轴和y轴数据 - 这一步往往也是创建函数
x = np.linspace(0,2*np.pi)

# 3.每一个子视图依次绘图
fig.set_figwidth(9)
fig.set_figheight(6)
ax11.plot(x,np.sin(x))
ax12.plot(x,np.cos(x))
ax13.plot(x,np.tanh(x))
ax21.plot(x,np.tan(x))
ax22.plot(x,np.cosh(x))
ax23.plot(x,np.sinh(x))
ax31.plot(x,np.sin(x) + np.cos(x))
ax32.plot(x,np.sin(x*x) + np.cos(x*x))
ax33.plot(x,np.sin(x)*np.cos(x))

# 紧凑显示，边框会比较小，可以注释掉该行查看效果
plt.tight_layout()

# 4.保存图像文件为图片格式
plt.savefig(
    './03th_img/img6.png', # 文件名：png、jpg、pdf
    dpi = 100, # 保存图片像素密度
    facecolor = 'white', # 视图与边界之间颜色设置
    edgecolor = 'red', # 视图边界颜色设置
    bbox_inches = 'tight'# 保存图片完整
)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# 1.创建绘图对象，指定尺寸为5*3英寸
fig = plt.figure(figsize=(8,6))

# 2.给定x轴和y轴数据 - 这一步往往也是创建函数
x = np.linspace(0,2*np.pi,200)

# 3.使用切片方式设置子视图
ax1 = plt.subplot(3,1,1) # 视图对象添加子视图
ax1.plot(x,np.sin(10*x))

# 设置ax1的标题，xlim、ylim、xlabel、ylabel等所有属性现在只能通过set_属性名的方法设置
ax1.set_title('ax1_title') # 设置小图的标题


ax2 = plt.subplot(3,3,(4,5)) # 视图对象添加子视图
ax2.set_facecolor('green')
ax2.plot(x,np.cos(x),color = 'red')


ax3 = plt.subplot(3,3,(6,9)) # 视图对象添加子视图
ax3.plot(x,np.sin(x) + np.cos(x))


ax4 = plt.subplot(3,3,7) # 视图对象添加子视图
ax4.plot([1,3],[2,4])


ax5 = plt.subplot(3,3,8) # 视图对象添加子视图
ax5.scatter([1,2,3], [0,2, 4])
ax5.set_xlabel('ax5_x',fontsize = 12)
ax5.set_ylabel('ax5_y',fontsize = 12)

# 4.保存图像文件为图片格式
plt.savefig(
    './03th_img/img7.png', # 文件名：png、jpg、pdf
    dpi = 100, # 保存图片像素密度
    facecolor = 'white', # 视图与边界之间颜色设置
    edgecolor = 'red', # 视图边界颜色设置
    bbox_inches = 'tight'# 保存图片完整
)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# 1.创建绘图对象，指定尺寸为5*3英寸
fig = plt.figure(figsize=(8,6))

# 2.给定x轴和y轴数据 - 这一步往往也是创建函数
x = np.linspace(0,2*np.pi,100)

# 3.使用subplot2grid方式设置子视图
# 子视图1
ax1 = plt.subplot2grid(shape = (3, 3),# 布局形状
                       loc = (0, 0), # 布局绘制位置
                       colspan=3) # 跨几列
ax1.plot(x,np.sin(10*x))

# 设置ax1的标题，xlim、ylim、xlabel、ylabel等所有属性现在只能通过set_属性名的方法设置
ax1.set_title('ax1_title') # 设置小图的标题

# 子视图2
ax2 = plt.subplot2grid((3, 3), (1, 0), colspan=2) # 跨两列
ax2.set_facecolor('green')
ax2.plot(x,np.cos(x),color = 'red')

# 子视图3
ax3 = plt.subplot2grid((3, 3), (1, 2), rowspan=2) # 跨两行
ax3.plot(x,np.sin(x) + np.cos(x))

# 子视图4
ax4 = plt.subplot2grid((3, 3), (2, 0))
ax4.plot([1,3],[2,4])

# 子视图5
ax5 = plt.subplot2grid((3, 3), (2, 1))
ax5.scatter([1,2,3], [0,2, 4])
ax5.set_xlabel('ax5_x',fontsize = 12)
ax5.set_ylabel('ax5_y',fontsize = 12)


# 4.保存图像文件为图片格式
plt.savefig(
    './03th_img/img8.png', # 文件名：png、jpg、pdf
    dpi = 100, # 保存图片像素密度
    facecolor = 'white', # 视图与边界之间颜色设置
    edgecolor = 'red', # 视图边界颜色设置
    bbox_inches = 'tight'# 保存图片完整
)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# 导入gridspec模块
import matplotlib.gridspec as gridspec

# 1.创建绘图对象，指定尺寸为5*3英寸
fig = plt.figure(figsize=(8,6))
x = np.linspace(0,2*np.pi,200)

# 2.将整个视图分成3x3布局
gs = gridspec.GridSpec(3, 3)

# 使用切片方式设置子视图
ax1 = fig.add_subplot(gs[0,:]) # 视图对象添加子视图
ax1.plot(x,np.sin(10*x))
# 设置ax1的标题，xlim、ylim、xlabel、ylabel等所有属性现在只能通过set_属性名的方法设置
ax1.set_title('ax1_title') # 设置小图的标题

ax2 = plt.subplot(gs[1, :2]) # 模块调用
ax2.set_facecolor('green')
ax2.plot(x,np.cos(x),color = 'red')

# 从第一行到最后，占1、2两行，后面的2表示只占用第二列，也就是最后的一列
ax3 = plt.subplot(gs[1:, 2])
ax3.plot(x,np.sin(x) + np.cos(x))

# 倒数第一行，只占第0列这一列
ax4 = plt.subplot(gs[-1, 0])
ax4.plot([1,3],[2,4])

# 倒数第一行，只占倒数第二列，由于总共三列，所以倒数第二列就是序号1的列
ax5 = plt.subplot(gs[-1, -2])
ax5.scatter([1,2,3], [0,2, 4])
ax5.set_xlabel('ax5_x',fontsize = 12)
ax5.set_ylabel('ax5_y',fontsize = 12)

# 4.保存图像文件为图片格式
plt.savefig(
    './03th_img/img9.png', # 文件名：png、jpg、pdf
    dpi = 100, # 保存图片像素密度
    facecolor = 'white', # 视图与边界之间颜色设置
    edgecolor = 'red', # 视图边界颜色设置
    bbox_inches = 'tight'# 保存图片完整
)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# 1.创建绘图对象，指定尺寸为5*3英寸
fig = plt.figure(figsize=(8,6))

# 2.给定x轴和y轴数据 - 这一步往往也是创建函数
x = np.linspace(-np.pi,np.pi,100)
data1 = np.exp(x)
data2 = np.sin(x)

plt.rcParams['font.size'] = 16 # 设置整体字体大小

ax1 = plt.gca() # 获取当前轴域
ax1.set_xlabel('time (s)') # 设置x轴标签
ax1.set_ylabel('exp', color='red') # 设置y轴标签
ax1.plot(x, data1, color='red') # 数据绘制
ax1.tick_params(axis='y', labelcolor='red') # 设置y轴刻度属性

ax2 = ax1.twinx() # 创建新axes实例，共享x轴，并设置
ax2.set_ylabel('sin', color='blue')
ax2.plot(x, data2, color='blue')
ax2.tick_params(axis='y', labelcolor='blue')
plt.tight_layout() # 紧凑布局

# 4.保存图像文件为图片格式
plt.savefig(
    './03th_img/img10.png', # 文件名：png、jpg、pdf
    dpi = 100, # 保存图片像素密度
    facecolor = 'white', # 视图与边界之间颜色设置
    edgecolor = 'red', # 视图边界颜色设置
    bbox_inches = 'tight'# 保存图片完整
)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# 1.创建绘图对象，指定尺寸为5*3英寸
fig = plt.figure(figsize=(8,6))

# 2.给定x轴和y轴数据 - 这一步往往也是创建函数
x = np.linspace(0.0, 5.0, 100)
y = np.cos(2*np.pi*x) * np.exp(-x)

# 3.指定字体的属性
font = {'fontsize': 20,
        'family': 'consolas',
        'color': 'red',
        'fontweight': 'bold'
       }

# 4.绘图
plt.plot(x, y, 'k')
plt.title('exponential decay',fontdict=font) # 设置标题
plt.suptitle('images',y = 1.05,fontdict = font,fontsize = 30) # 添加中心化标题
plt.text(x = 2, y = 0.65, # 横纵坐标位置
s = r'$\cos(2 \pi t) \exp(-t)$') # 文本内容 - 这里是写数学公式
plt.xlabel('time (s)') # xy轴分别添加标签
plt.ylabel('voltage (mV)')

# 4.保存图像文件为图片格式
plt.savefig(
    './03th_img/img11.png', # 文件名：png、jpg、pdf
    dpi = 100, # 保存图片像素密度
    facecolor = 'white', # 视图与边界之间颜色设置
    edgecolor = 'red', # 视图边界颜色设置
    bbox_inches = 'tight'# 保存图片完整
)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# 1.创建绘图对象，指定尺寸为5*3英寸
fig = plt.figure(figsize=(8,6))

# 准备数据
data = np.random.randint(0,10,size=(10,2))

# scatter方法绘制散点图
plt.scatter(
    data[:,0], # 拿横坐标，二维数组的第一列的值
    data[:,1], # 拿纵坐标，二维数组的第二列的值
    color = 'green',
    marker = '*',
    s = 100
)

for i in range(9):
    start = data[i] # 给个起点，指定起点坐标值
    end = data[i + 1] # 给个终点，指定坐标坐标值
    
    # 绘制箭头
    plt.arrow(x = start[0],y = start[1], # 起点坐标
              dx = end[0] - start[0],dy = end[1] - start[1], # 水平和竖直的距离
              lw = 2, # 线宽
              head_width = 0.2, # 箭头的宽度
              length_includes_head = True # 长度计算包含箭头长度
             )
    
    # 每个点添加个文本
    plt.text(start[0],start[1],i,fontsize = 18,color = 'red')
    
    # 最后一个点绘制
    if i == 8:
        plt.text(end[0],end[1],i + 1,fontsize = 18,color = 'green')
    
        
# 4.保存图像文件为图片格式
plt.savefig(
    './03th_img/img12.png', # 文件名：png、jpg、pdf
    dpi = 100, # 保存图片像素密度
    facecolor = 'white', # 视图与边界之间颜色设置
    edgecolor = 'red', # 视图边界颜色设置
    bbox_inches = 'tight'# 保存图片完整
)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# 创建绘图对象
fig, ax = plt.subplots()

# 准备数据
x = np.arange(0.0, 5.0, 0.01)
y = np.cos(2*np.pi*x)

# 绘图
line, = ax.plot(x,y,lw=2)

# 添加注释
ax.annotate('local max', # 文本内容
            xy=(2, 1), # 箭头指向位置
            xytext=(3, 1.5), # 文本位置
            arrowprops=dict(facecolor='black', shrink=0.05)) # 箭头

ax.annotate('local min',
            xy = (2.5,-1),
            xytext = (4,-1.8),
            arrowprops = dict(facecolor = 'black',
                              width = 2, # 箭头宽度
                              headwidth = 10,# 箭头头部宽度
                              headlength = 10, # 箭头头部长度
                              shrink = 0.1)) # 箭头两端收缩的百分比（占总长）

ax.annotate('median',
            xy = (2.25,0),
            xytext = (0.5,-1.8),
            arrowprops = dict(arrowstyle = '-|>'), # 箭头样式
            fontsize = 20)

ax.set_ylim(-2, 2)
        
# 4.保存图像文件为图片格式
plt.savefig(
    './03th_img/img13.png', # 文件名：png、jpg、pdf
    dpi = 100, # 保存图片像素密度
    facecolor = 'white', # 视图与边界之间颜色设置
    edgecolor = 'red', # 视图边界颜色设置
    bbox_inches = 'tight'# 保存图片完整
)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

def annotate_con_style(ax, connectionstyle):
    x1, y1 = 3,2
    x2, y2 = 8,6
    ax.plot([x1, x2], [y1, y2], ".")
    ax.annotate(
        text = '',
        xy=(x1, y1), # 相当于B点，arrow head
        xytext=(x2, y2), # 相当于A点，arrow tail
        arrowprops=dict(
            arrowstyle='->', 
            color='red',
            shrinkA = 5,
            shrinkB = 5,
            connectionstyle = connectionstyle # 设置箭头连接形状
        )
    )
    
    ax.text(0.05, 0.95, connectionstyle.replace(",", "\n"),
            transform=ax.transAxes, # 相对坐标
            ha="left", va="top")# 指定对齐方式

# 常用箭头连接样式
fig, axs = plt.subplots(3, 5, figsize=(9,6))
annotate_con_style(axs[0, 0], "angle,angleA=90,angleB=0")
annotate_con_style(axs[1, 0], "angle3,angleA=0,angleB=90")
annotate_con_style(axs[2, 0], "angle3,angleA=0,angleB=150")
annotate_con_style(axs[0, 1], "arc3,rad=0.")
annotate_con_style(axs[1, 1], "arc3,rad=0.3")
annotate_con_style(axs[2, 1], "arc3,rad=-0.3")
annotate_con_style(axs[0, 2], "angle,angleA=-90,angleB=180,rad=0")
annotate_con_style(axs[1, 2], "angle,angleA=-90,angleB=180,rad=5")
annotate_con_style(axs[2, 2], "angle,angleA=-90,angleB=10,rad=5")
annotate_con_style(axs[0, 3], "arc,angleA=-90,angleB=0,armA=30,armB=30,rad=0")
annotate_con_style(axs[1, 3], "arc,angleA=-90,angleB=0,armA=30,armB=30,rad=5")
annotate_con_style(axs[2, 3], "arc,angleA=-90,angleB=0,armA=0,armB=40,rad=0")
annotate_con_style(axs[0, 4], "bar,fraction=0.3")
annotate_con_style(axs[1, 4], "bar,fraction=-0.3")
annotate_con_style(axs[2, 4], "bar,angle=180,fraction=-0.2")

for ax in axs.flat:
    # 设置轴域刻度
    ax.set(xlim=(0, 10), ylim=(0, 10),xticks = [],yticks = [],aspect=1)
    
fig.tight_layout(pad=0.2)

# 4.保存图像文件为图片格式
plt.savefig(
    './03th_img/img14.png', # 文件名：png、jpg、pdf
    dpi = 100, # 保存图片像素密度
    facecolor = 'white', # 视图与边界之间颜色设置
    edgecolor = 'red', # 视图边界颜色设置
    bbox_inches = 'tight'# 保存图片完整
)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# 创建绘图对象
plt.figure(figsize=(8,6))

# 准备数据
x = np.random.randint(0,10,size = 15)

# 一图多线
plt.plot(x,marker = '*',color = 'r')
plt.plot(x.cumsum(),marker = 'o')

# 4.保存图像文件为图片格式
plt.savefig(
    './03th_img/img15.png', # 文件名：png、jpg、pdf
    dpi = 100, # 保存图片像素密度
    facecolor = 'white', # 视图与边界之间颜色设置
    edgecolor = 'red', # 视图边界颜色设置
    bbox_inches = 'tight'# 保存图片完整
)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# 创建绘图对象
plt.figure(figsize=(8,6))

# 准备数据
x = np.random.randint(0,10,size = 15)

# 多图布局
fig,axs = plt.subplots(2,1)
fig.set_figwidth(9)
fig.set_figheight(6)
axs[0].plot(x,marker = '*',color = 'red')
axs[1].plot(x.cumsum(),marker = 'o')

# 4.保存图像文件为图片格式
plt.savefig(
    './03th_img/img16.png', # 文件名：png、jpg、pdf
    dpi = 100, # 保存图片像素密度
    facecolor = 'white', # 视图与边界之间颜色设置
    edgecolor = 'red', # 视图边界颜色设置
    bbox_inches = 'tight'# 保存图片完整
)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# 横坐标label
labels = ['G1', 'G2', 'G3', 'G4', 'G5','G6'] # 级别

# 两组数据
men_means = np.random.randint(20,35,size = 6)
women_means = np.random.randint(20,35,size = 6)

men_std = np.random.randint(1,7,size = 6)
women_std = np.random.randint(1,7,size = 6)

# 柱宽度
width = 0.35

# 绘图
plt.bar(labels, # 横坐标
        men_means, # 柱高
        width, # 线宽
        yerr=4, # 误差条
        label='Men')#标签

plt.bar(labels, women_means, width, yerr=2, bottom=men_means,label='Women')

plt.ylabel('Scores')

plt.title('Scores by group and gender')

# 设置图例 - 效果是于绘图左右上角显示每种颜色的柱对应的数据
plt.legend()

# 4.保存图像文件为图片格式
plt.savefig(
    './03th_img/img17.png', # 文件名：png、jpg、pdf
    dpi = 100, # 保存图片像素密度
    facecolor = 'white', # 视图与边界之间颜色设置
    edgecolor = 'red', # 视图边界颜色设置
    bbox_inches = 'tight'# 保存图片完整
)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# 横坐标label
labels = ['G1', 'G2', 'G3', 'G4', 'G5','G6'] # 级别

# 数据准备
men_means = np.random.randint(20,35,size = 6)
women_means = np.random.randint(20,35,size = 6)
x = np.arange(len(men_means))

# 创建绘图对象
plt.figure(figsize=(9,6))

rects1 = plt.bar(x - width/2, men_means, width) # 返回绘图区域对象
rects2 = plt.bar(x + width/2, women_means, width)

# 设置标签标题，图例
plt.ylabel('Scores')
plt.title('Scores by group and gender')
plt.xticks(x,labels)
plt.legend(['Men','Women'])

# 添加注释
def set_label(rects):
    for rect in rects:
        height = rect.get_height() # 获取高度
        plt.text(x = rect.get_x() + rect.get_width()/2, # 水平坐标
                 y = height + 0.5, # 竖直坐标
                 s = height, # 文本
                 ha = 'center') # 水平居中

set_label(rects1)
set_label(rects2)
plt.tight_layout() # 设置紧凑布局
        
# 4.保存图像文件为图片格式
plt.savefig(
    './03th_img/img18.png', # 文件名：png、jpg、pdf
    dpi = 100, # 保存图片像素密度
    facecolor = 'white', # 视图与边界之间颜色设置
    edgecolor = 'red', # 视图边界颜色设置
    bbox_inches = 'tight'# 保存图片完整
)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# 数据准备
r = np.arange(0, 4*np.pi, 0.01) # 弧度值
y = np.linspace(0,2,len(r)) # 目标值

ax = plt.subplot(111,projection = 'polar',facecolor = 'lightgreen') # 通过projection属性定义极坐标

# 绘图
ax.plot(r, y,color = 'red')

ax.set_rmax(3) # 设置半径最大值

ax.set_rticks([0.5, 1, 1.5, 2]) # 设置半径刻度

ax.set_rlabel_position(-22.5) # 设置半径刻度位置

ax.grid(True) # 网格线

ax.set_title("A line plot on a polar axis", va='center',ha = 'center',pad = 30)

# 4.保存图像文件为图片格式
plt.savefig(
    './03th_img/img19.png', # 文件名：png、jpg、pdf
    dpi = 100, # 保存图片像素密度
    facecolor = 'white', # 视图与边界之间颜色设置
    edgecolor = 'red', # 视图边界颜色设置
    bbox_inches = 'tight'# 保存图片完整
)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

N = 8 # 分成8份

# 数据准备
theta = np.linspace(0.0, 2 * np.pi, N, endpoint=False)
radii = np.random.randint(3,15,size = N)
width = np.pi / 4
colors = np.random.rand(8,3) # 随机生成颜色

# 绘图
ax = plt.subplot(111, projection='polar') # polar表示极坐标
ax.bar(theta, radii, width=width, bottom=0.0,color = colors)

# 4.保存图像文件为图片格式
plt.savefig(
    './03th_img/img20.png', # 文件名：png、jpg、pdf
    dpi = 100, # 保存图片像素密度
    facecolor = 'white', # 视图与边界之间颜色设置
    edgecolor = 'red', # 视图边界颜色设置
    bbox_inches = 'tight'# 保存图片完整
)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# 数据准备
mu = 100 # 平均值
sigma = 15 # 标准差
x = np.random.normal(loc = mu,scale = 15,size = 10000)

# 创建绘图对象
fig, ax = plt.subplots()

n, bins, patches = ax.hist(x, 200, density=True) # 直方图

# 概率密度函数
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) * np.exp(-0.5 * (1 / sigma * (bins - mu))**2))

# 绘图
plt.plot(bins, y, '--')
plt.xlabel('Smarts')
plt.ylabel('Probability density')
plt.title(r'Histogram of IQ: $\mu=100$, $\sigma=15$')

# 紧凑布局
fig.tight_layout()

# 4.保存图像文件为图片格式
plt.savefig(
    './03th_img/img21.png', # 文件名：png、jpg、pdf
    dpi = 100, # 保存图片像素密度
    facecolor = 'white', # 视图与边界之间颜色设置
    edgecolor = 'red', # 视图边界颜色设置
    bbox_inches = 'tight'# 保存图片完整
)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# 准备数据
data = np.random.normal(size=(500,4))

# label
lables = ['A','B','C','D']

# 用Matplotlib画箱线图
plt.boxplot(data,1,'gD',labels=lables) # 红色的圆点是异常值

# 4.保存图像文件为图片格式
plt.savefig(
    './03th_img/img22.png', # 文件名：png、jpg、pdf
    dpi = 100, # 保存图片像素密度
    facecolor = 'white', # 视图与边界之间颜色设置
    edgecolor = 'red', # 视图边界颜色设置
    bbox_inches = 'tight'# 保存图片完整
)
# Out:
# C:\Users\10433\AppData\Local\Temp\ipykernel_31600\706416823.py:12: MatplotlibDeprecationWarning: Passing the notch parameter of boxplot() positionally is deprecated since Matplotlib 3.10; the parameter will become keyword-only in 3.12.
#   plt.boxplot(data,1,'gD',labels=lables) # 红色的圆点是异常值
# C:\Users\10433\AppData\Local\Temp\ipykernel_31600\706416823.py:12: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data,1,'gD',labels=lables) # 红色的圆点是异常值

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# 准备数据
data = np.random.randn(100,2)
s = np.random.randint(100,300,size = 100)
color = np.random.randn(100)

# 绘制散点图
plt.scatter(
    data[:,0], # 横坐标
    data[:,1], # 纵坐标
    s = s, # 尺寸
    c = color, # 颜色
    alpha = 0.5) # 透明度

# 4.保存图像文件为图片格式
plt.savefig(
    './03th_img/img23.png', # 文件名：png、jpg、pdf
    dpi = 100, # 保存图片像素密度
    facecolor = 'white', # 视图与边界之间颜色设置
    edgecolor = 'red', # 视图边界颜色设置
    bbox_inches = 'tight'# 保存图片完整
)

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd

# 解决中文字体乱码的问题
matplotlib.rcParams['font.sans-serif']='Kaiti'

labels =["五星","四星","三星","二星","一星"] # 标签
percent = [95,261,105,30,9] # 某市星级酒店数量

# 设置图片大小和分辨率，创建绘图对象
fig=plt.figure(figsize=(5,5), dpi=150)

# 偏移中心量，突出某一部分
explode = (0, 0.1, 0, 0, 0)

# 绘制饼图 - 使用pie方法
# autopct显示百分比，这里保留一位小数；shadow控制是否显示阴影
plt.pie(x = percent, # 数据
        explode=explode, # 偏移中心量
        labels=labels, # 显示标签
        autopct='%0.1f%%', # 显示百分比
        shadow=True) # 阴影，3D效果

# 4.保存图像文件为图片格式
plt.savefig(
    './03th_img/img24.png', # 文件名：png、jpg、pdf
    dpi = 100, # 保存图片像素密度
    facecolor = 'white', # 视图与边界之间颜色设置
    edgecolor = 'red', # 视图边界颜色设置
    bbox_inches = 'tight'# 保存图片完整
)

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd

# 解决中文字体乱码的问题
matplotlib.rcParams['font.sans-serif']='Kaiti'

# 创建绘图对象
fig=plt.figure(figsize=(5,5),dpi=100)

#数据集，p1, p2分别对应外部、内部百分比例
p1=[43,25,32]
p2=[7,22,14,5,14,6,32]

labels = ['小狗','小猫','小鸟']
def func(pct):
    return r'%0.1f'%(pct) + '%'

plt.pie(
    p1,
    autopct=lambda pct: func(pct),
    radius=1, # 半径
    pctdistance=0.85, # 百分比位置
    wedgeprops=dict(linewidth=3,width=0.4,edgecolor='w'),# 饼图格式：间隔线宽、饼图宽度、边界颜色
    labels=labels
)

# 绘制内部饼图
plt.pie(
    p2,
    autopct='%0.1f%%',
    radius=0.7,
    pctdistance=0.7,
    wedgeprops=dict(linewidth=3,width=0.7,edgecolor='w')
)

# 设置图例标题、位置，frameon控制是否显示图例边框，bbox_to_anchor控制图例显示在饼图的外面
plt.legend(labels,loc = 'upper right',bbox_to_anchor = (0.75,0,0.4,1),title = '宠物占比')

# 4.保存图像文件为图片格式
plt.savefig(
    './03th_img/img25.png', # 文件名：png、jpg、pdf
    dpi = 100, # 保存图片像素密度
    facecolor = 'white', # 视图与边界之间颜色设置
    edgecolor = 'red', # 视图边界颜色设置
    bbox_inches = 'tight'# 保存图片完整
)

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
 
 
results = [{"大学英语": 87, "高等数学": 79, "体育": 95, "计算机基础": 92, "程序设计": 85},
           {"大学英语": 80, "高等数学": 90, "体育": 91, "计算机基础": 85, "程序设计": 88}]
data_length = len(results[0])
# 将极坐标根据数据长度进行等分
angles = np.linspace(0, 2*np.pi, data_length, endpoint=False)
labels = [key for key in results[0].keys()]
score = [[v for v in result.values()] for result in results]

# 使雷达图数据封闭
score_a = np.concatenate((score[0], [score[0][0]]))
score_b = np.concatenate((score[1], [score[1][0]]))
angles = np.concatenate((angles, [angles[0]]))
labels = np.concatenate((labels, [labels[0]]))

# 设置图形的大小
fig = plt.figure(figsize=(8, 6), dpi=100)

# 新建一个子图
ax = plt.subplot(111, polar=True)

# 绘制雷达图
ax.plot(angles, score_a, color='g')
ax.plot(angles, score_b, color='b')

# 设置雷达图中每一项的标签显示
ax.set_thetagrids(angles*180/np.pi, labels)

# 设置雷达图的0度起始位置
ax.set_theta_zero_location('N')

# 设置雷达图的坐标刻度范围
ax.set_rlim(0, 100)

# 设置雷达图的坐标值显示角度，相对于起始角度的偏移量
ax.set_rlabel_position(270)
ax.set_title("计算机专业大一（上）")
plt.legend(["弓长张", "口天吴"], loc='best')

# 4.保存图像文件为图片格式
plt.savefig(
    './03th_img/img26.png', # 文件名：png、jpg、pdf
    dpi = 100, # 保存图片像素密度
    facecolor = 'white', # 视图与边界之间颜色设置
    edgecolor = 'red', # 视图边界颜色设置
    bbox_inches = 'tight'# 保存图片完整
)

# %%
import numpy as np
import matplotlib.pyplot as plt

# 数据准备
x = np.linspace(0,60,300)
y = np.sin(x)
z = np.cos(x)

# 准备二维画布
fig = plt.figure(figsize=(9,6)) # 二维图形
ax3 = fig.add_subplot(111, projection='3d')
ax3.plot(x,y,z) # 3维折线图

# 3维散点图
ax3.scatter(np.random.rand(50)*60,np.random.rand(50),np.random.rand(50), color = 'red',s = 100)

# 4.保存图像文件为图片格式
plt.savefig(
    './03th_img/img27.png', # 文件名：png、jpg、pdf
    dpi = 100, # 保存图片像素密度
    facecolor = 'white', # 视图与边界之间颜色设置
    edgecolor = 'red', # 视图边界颜色设置
    bbox_inches = 'tight'# 保存图片完整
)
# Out:
# C:\Users\10433\AppData\Local\Temp\ipykernel_31600\3621060565.py:18: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) KaiTi.
#   plt.savefig(

# %%
import numpy as np
import matplotlib.pyplot as plt

month = np.arange(1,5)
# 每个月 4周 每周都会产生数据
# 三个维度：月、周、销量
fig = plt.figure(figsize=(9,6))
ax3 = fig.add_subplot(111, projection='3d')

for m in month:
    ax3.bar(
        np.arange(4),
        np.random.randint(1,10,size = 4),
        zs = m ,
        zdir = 'x',# 在哪个方向上，一排排排列
        alpha = 0.7,# alpha 透明度
        width = 0.5
    )
    
ax3.set_xlabel('X',fontsize = 18,color = 'red')
ax3.set_ylabel('Y',fontsize = 18,color = 'red')
ax3.set_zlabel('Z',fontsize = 18,color = 'green')

# 4.保存图像文件为图片格式
plt.savefig(
    './03th_img/img28.png', # 文件名：png、jpg、pdf
    dpi = 100, # 保存图片像素密度
    facecolor = 'white', # 视图与边界之间颜色设置
    edgecolor = 'red', # 视图边界颜色设置
    bbox_inches = 'tight'# 保存图片完整
)
